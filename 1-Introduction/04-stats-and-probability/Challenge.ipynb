# %% [markdown]
# First basemen are older than second basemen

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/saisanjaypotluri/Data-Science-For-Beginners/main/data/SOCR_MLB.tsv"

df = pd.read_csv(
    url,
    sep="\t",
    header=None,
    names=["Name", "Team", "Role", "Weight", "Height", "Age"]
)

# %%
import scipy.stats

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h

for p in [0.85, 0.9, 0.95]:
    m, h = mean_confidence_interval(df['Age'].fillna(method='pad'),p)
    print(f"p={p:.2f}, mean = {m:.2f} ± {h:.2f}")
# Out:
# p=0.85, mean = 28.74 ± 0.19
# p=0.90, mean = 28.74 ± 0.22
# p=0.95, mean = 28.74 ± 0.26
# /var/folders/w6/9j_4svy105d4799q3_5bt54m0000gn/T/ipykernel_68612/408693664.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   m, h = mean_confidence_interval(df['Age'].fillna(method='pad'),p)

# %%
for p in [0.85,0.9,0.95]:
    m1, h1 = mean_confidence_interval(df.loc[df['Role']=='First_Baseman',['Age']],p)
    m2, h2 = mean_confidence_interval(df.loc[df['Role']=='Second_Baseman',['Age']],p)
    print(f'Conf={p:.2f}, 1st basemen Age: {m1-h1[0]:.2f}..{m1+h1[0]:.2f}, 2nd basemen Age: {m2-h2[0]:.2f}..{m2+h2[0]:.2f}')
# Out:
# Conf=0.85, 1st basemen Age: 28.56..30.39, 2nd basemen Age: 28.18..29.87
# Conf=0.90, 1st basemen Age: 28.42..30.53, 2nd basemen Age: 28.06..29.99
# Conf=0.95, 1st basemen Age: 28.22..30.73, 2nd basemen Age: 27.87..30.18

# %% [markdown]
# Height of 1st base man vs 3rd base man

# %%
for p in [0.85,0.9,0.95]:
    m1, h1 = mean_confidence_interval(df.loc[df['Role']=='First_Baseman',['Height']],p)
    m2, h2 = mean_confidence_interval(df.loc[df['Role']=='Second_Baseman',['Height']],p)
    print(f'Conf={p:.2f}, 1st basemen Height: {m1-h1[0]:.2f}..{m1+h1[0]:.2f}, 2nd basemen Height: {m2-h2[0]:.2f}..{m2+h2[0]:.2f}')
# Out:
# Conf=0.85, 1st basemen Height: 209.36..216.86, 2nd basemen Height: 182.24..186.45
# Conf=0.90, 1st basemen Height: 208.82..217.40, 2nd basemen Height: 181.93..186.76
# Conf=0.95, 1st basemen Height: 207.97..218.25, 2nd basemen Height: 181.45..187.24

# %%
for p in [0.85,0.9,0.95]:
    m1, h1 = mean_confidence_interval(df.loc[df['Role']=='Shortstop',['Height']],p)
    m2, h2 = mean_confidence_interval(df.loc[df['Role']=='Second_Baseman',['Height']],p)
    print(f'Conf={p:.2f}, 1st basemen Height: {m1-h1[0]:.2f}..{m1+h1[0]:.2f}, 2nd basemen Height: {m2-h2[0]:.2f}..{m2+h2[0]:.2f}')
# Out:
# Conf=0.85, 1st basemen Height: 179.98..185.86, 2nd basemen Height: 182.24..186.45
# Conf=0.90, 1st basemen Height: 179.55..186.29, 2nd basemen Height: 181.93..186.76
# Conf=0.95, 1st basemen Height: 178.89..186.96, 2nd basemen Height: 181.45..187.24
